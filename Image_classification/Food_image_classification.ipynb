# %% [markdown]
# #food data classification

# %%
import google.colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.45)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)

# %%
import optuna
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import os

# %%
torch.manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# #Mount google drive

# %%
DATASET_ROOT = "/content/drive/MyDrive/Pytorch/Image_classification"

TRAIN_DIR = os.path.join(DATASET_ROOT, "train")
TEST_DIR  = os.path.join(DATASET_ROOT, "test")

NUM_CLASSES = 3        # You said 3 categories
IMG_SIZE = 128         # Can change to 224 if needed

# %% [markdown]
# #Data Augmentation

# %%
# ==============================
# Data Augmentation
# ==============================
train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(15),
    transforms.RandomAffine(0, translate=(0.1, 0.1)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# #Dtaset DataLoader

# %%
class CustomDataset(Dataset):
    def __init__(self, features, labels, transform=None):
        self.features = torch.tensor(features, dtype=torch.float32).reshape(-1, 1, 28, 28)
        self.labels = torch.tensor(labels, dtype=torch.long)
        self.transform = transform

    def __getitem__(self, index):
        feature, label = self.features[index], self.labels[index]
        if self.transform:
            feature = self.transform(feature.squeeze(0).numpy())  # Apply transform
        return feature, label

    def __len__(self):
        return len(self.features)

# %%
# Use augmentations in training data
train_dataset = datasets.ImageFolder(root=TRAIN_DIR, transform=train_transform)
test_dataset  = datasets.ImageFolder(root=TEST_DIR,  transform=test_transform)

# %%
print("Class mapping:", train_dataset.class_to_idx)
# Out:
# Class mapping: {'pizza': 0, 'steak': 1, 'sushi': 2}

# %% [markdown]
# #CNN Model

# %%
class DynamicCNN(nn.Module):
    def __init__(self, num_conv_layers, num_filters, kernel_size,
                 num_fc_layers, fc_layer_size, dropout_rate):
        super().__init__()

        layers = []
        in_channels = 3  # RGB images

        for _ in range(num_conv_layers):
            layers.append(nn.Conv2d(in_channels,num_filters,kernel_size=kernel_size,padding='same'))
            layers.append(nn.BatchNorm2d(num_filters))
            layers.append(nn.ReLU())
            layers.append(nn.MaxPool2d(2))
            in_channels = num_filters

        self.features = nn.Sequential(*layers)

        # 🔑 DYNAMIC FEATURE SIZE COMPUTATION
        with torch.no_grad():
            dummy = torch.zeros(1, 3, IMG_SIZE, IMG_SIZE)
            dummy_out = self.features(dummy)
            feature_dim = dummy_out.view(1, -1).shape[1]

        fc_layers = [nn.Flatten()]
        for _ in range(num_fc_layers):
            fc_layers.append(nn.Linear(feature_dim, fc_layer_size))
            fc_layers.append(nn.ReLU())
            fc_layers.append(nn.Dropout(dropout_rate))
            feature_dim = fc_layer_size

        fc_layers.append(nn.Linear(feature_dim, NUM_CLASSES))
        self.classifier = nn.Sequential(*fc_layers)

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# #Objective Function

# %%
# ==============================
# Optuna Objective Function
# ==============================
def objective(trial):

    num_conv_layers = trial.suggest_int("num_conv_layers", 1, 3)
    num_filters = trial.suggest_categorical("num_filters", [16, 32, 64, 128])
    kernel_size = trial.suggest_categorical("kernel_size", [3, 5])
    num_fc_layers = trial.suggest_int("num_fc_layers", 1, 3)
    fc_layer_size = trial.suggest_categorical("fc_layer_size", [64, 128, 256])
    dropout_rate = trial.suggest_float("dropout_rate", 0.2, 0.5,step=0.1)
    learning_rate = trial.suggest_float("learning_rate", 1e-4, 1e-2, log=True)
    weight_decay  = trial.suggest_float("weight_decay", 1e-5, 1e-2, log=True)
    optimizer_name = trial.suggest_categorical("optimizer", ["SGD", "Adam", "RMSprop"])
    batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
    num_epochs = trial.suggest_int("num_epochs", 10, 70,step=10)

    # Model
    model = DynamicCNN(num_conv_layers, num_filters, kernel_size, num_fc_layers, fc_layer_size, dropout_rate).to(device)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    if optimizer_name == "SGD":
        optimizer = optim.SGD(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_name == "Adam":
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    else:
        optimizer = optim.RMSprop(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    criterion = nn.CrossEntropyLoss()

    # Training
    for _ in range(num_epochs):
        model.train()
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

    # Evaluation
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    return accuracy

# %%
pruner = optuna.pruners.MedianPruner()
study = optuna.create_study(direction='maximize', pruner=pruner)
study.optimize(objective, n_trials=50)  # Run 5 trials
# Out:
# [I 2025-12-30 07:22:37,021] A new study created in memory with name: no-name-82aba831-f85d-4ba6-a00b-a31613639091
# [I 2025-12-30 07:23:26,927] Trial 0 finished with value: 0.4533333333333333 and parameters: {'num_conv_layers': 2, 'num_filters': 64, 'kernel_size': 5, 'num_fc_layers': 3, 'fc_layer_size': 256, 'dropout_rate': 0.2, 'learning_rate': 0.00026936182474525497, 'weight_decay': 0.002267882203126903, 'optimizer': 'RMSprop', 'batch_size': 32, 'num_epochs': 30}. Best is trial 0 with value: 0.4533333333333333.
# [I 2025-12-30 07:24:39,416] Trial 1 finished with value: 0.32 and parameters: {'num_conv_layers': 1, 'num_filters': 64, 'kernel_size': 5, 'num_fc_layers': 1, 'fc_layer_size': 128, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.005220674037788458, 'weight_decay': 1.4977566559250385e-05, 'optimizer': 'RMSprop', 'batch_size': 64, 'num_epochs': 50}. Best is trial 0 with value: 0.4533333333333333.
# [I 2025-12-30 07:25:11,208] Trial 2 finished with value: 0.36 and parameters: {'num_conv_layers': 2, 'num_filters': 128, 'kernel_size': 5, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.5, 'learning_rate': 0.007205154033604406, 'weight_decay': 5.4126387126291794e-05, 'optimizer': 'SGD', 'batch_size': 32, 'num_epochs': 20}. Best is trial 0 with value: 0.4533333333333333.
# [I 2025-12-30 07:26:08,689] Trial 3 finished with value: 0.3333333333333333 and parameters: {'num_conv_layers': 2, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 2, 'fc_layer_size': 64, 'dropout_rate': 0.5, 'learning_rate': 0.0014239120750171616, 'weight_decay': 0.00034584050750506595, 'optimizer': 'RMSprop', 'batch_size': 64, 'num_epochs': 40}. Best is trial 0 with value: 0.4533333333333333.
# [I 2025-12-30 07:27:06,057] Trial 4 finished with value: 0.5866666666666667 and parameters: {'num_conv_layers': 1, 'num_filters': 32, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 64, 'dropout_rate': 0.4, 'learning_rate': 0.0001798450929145719, 'weight_decay': 8.972912787618502e-05, 'optimizer': 'RMSprop', 'batch_size': 32, 'num_epochs': 40}. Best is trial 4 with value: 0.5866666666666667.
# [I 2025-12-30 07:28:03,099] Trial 5 finished with value: 0.3333333333333333 and parameters: {'num_conv_layers': 1, 'num_filters': 32, 'kernel_size': 3, 'num_fc_layers': 2, 'fc_layer_size': 128, 'dropout_rate': 0.5, 'learning_rate': 0.006599257259130803, 'weight_decay': 0.00022886237488537156, 'optimizer': 'Adam', 'batch_size': 64, 'num_epochs': 40}. Best is trial 4 with value: 0.5866666666666667.
# [I 2025-12-30 07:28:32,483] Trial 6 finished with value: 0.48 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 5, 'num_fc_layers': 1, 'fc_layer_size': 64, 'dropout_rate': 0.4, 'learning_rate': 0.00146115107616615, 'weight_decay': 0.00015929502448461925, 'optimizer': 'Adam', 'batch_size': 32, 'num_epochs': 20}. Best is trial 4 with value: 0.5866666666666667.
# [I 2025-12-30 07:29:43,304] Trial 7 finished with value: 0.44 and parameters: {'num_conv_layers': 2, 'num_filters': 64, 'kernel_size': 5, 'num_fc_layers': 2, 'fc_layer_size': 128, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.00022292529616221773, 'weight_decay': 0.000977951304689213, 'optimizer': 'SGD', 'batch_size': 64, 'num_epochs': 50}. Best is trial 4 with value: 0.5866666666666667.
# [I 2025-12-30 07:30:28,419] Trial 8 finished with value: 0.41333333333333333 and parameters: {'num_conv_layers': 2, 'num_filters': 32, 'kernel_size': 5, 'num_fc_layers': 2, 'fc_layer_size': 64, 'dropout_rate': 0.4, 'learning_rate': 0.006244580462389892, 'weight_decay': 0.00018746321629233, 'optimizer': 'Adam', 'batch_size': 16, 'num_epochs': 30}. Best is trial 4 with value: 0.5866666666666667.
# [I 2025-12-30 07:31:12,957] Trial 9 finished with value: 0.52 and parameters: {'num_conv_layers': 2, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 2, 'fc_layer_size': 256, 'dropout_rate': 0.5, 'learning_rate': 0.0025185896421795555, 'weight_decay': 0.00014763893526862333, 'optimizer': 'Adam', 'batch_size': 16, 'num_epochs': 30}. Best is trial 4 with value: 0.5866666666666667.
# [I 2025-12-30 07:32:54,781] Trial 10 finished with value: 0.48 and parameters: {'num_conv_layers': 1, 'num_filters': 32, 'kernel_size': 3, 'num_fc_layers': 3, 'fc_layer_size': 64, 'dropout_rate': 0.2, 'learning_rate': 0.00010092599808468453, 'weight_decay': 1.690215167197757e-05, 'optimizer': 'RMSprop', 'batch_size': 32, 'num_epochs': 70}. Best is trial 4 with value: 0.5866666666666667.
# [I 2025-12-30 07:34:22,135] Trial 11 finished with value: 0.6533333333333333 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0006838863826574364, 'weight_decay': 6.511213579584498e-05, 'optimizer': 'Adam', 'batch_size': 16, 'num_epochs': 60}. Best is trial 11 with value: 0.6533333333333333.
# [I 2025-12-30 07:36:05,467] Trial 12 finished with value: 0.6933333333333334 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0005021091640484274, 'weight_decay': 5.032123536172192e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 70}. Best is trial 12 with value: 0.6933333333333334.
# [I 2025-12-30 07:37:49,260] Trial 13 finished with value: 0.6266666666666667 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.0005132185533439911, 'weight_decay': 4.481709120457303e-05, 'optimizer': 'Adam', 'batch_size': 16, 'num_epochs': 70}. Best is trial 12 with value: 0.6933333333333334.
# [I 2025-12-30 07:39:16,044] Trial 14 finished with value: 0.52 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0006060802839337567, 'weight_decay': 0.00952849071081197, 'optimizer': 'SGD', 'batch_size': 16, 'num_epochs': 60}. Best is trial 12 with value: 0.6933333333333334.
# [I 2025-12-30 07:40:43,914] Trial 15 finished with value: 0.7066666666666667 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0005794624755319799, 'weight_decay': 2.8848686263950447e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:42:11,836] Trial 16 finished with value: 0.6133333333333333 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.00037339918850282615, 'weight_decay': 3.0478166072429448e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:43:54,331] Trial 17 finished with value: 0.6266666666666667 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 2, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.001030579233084585, 'weight_decay': 1.0405928940371194e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:45:08,715] Trial 18 finished with value: 0.48 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 3, 'fc_layer_size': 256, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.0024870149198307307, 'weight_decay': 2.3395447190023207e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 50}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:46:38,296] Trial 19 finished with value: 0.7066666666666667 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.5, 'learning_rate': 0.0003899624436042344, 'weight_decay': 0.0005518198907495279, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:48:07,573] Trial 20 finished with value: 0.5333333333333333 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 2, 'fc_layer_size': 128, 'dropout_rate': 0.5, 'learning_rate': 0.00012614934722391373, 'weight_decay': 0.000456579019541397, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:49:52,187] Trial 21 finished with value: 0.6133333333333333 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.5, 'learning_rate': 0.00036798241839620265, 'weight_decay': 0.0008162412656974279, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:51:21,995] Trial 22 finished with value: 0.4533333333333333 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0009745098444177633, 'weight_decay': 0.0015134441046615783, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:52:36,456] Trial 23 finished with value: 0.6933333333333334 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0003596436737480652, 'weight_decay': 9.27159676296484e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 50}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:52:52,005] Trial 24 finished with value: 0.5733333333333334 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.5, 'learning_rate': 0.0008143203273066358, 'weight_decay': 0.005262933621622136, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 10}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:54:33,127] Trial 25 finished with value: 0.49333333333333335 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0004661457250129638, 'weight_decay': 0.0005916652879010641, 'optimizer': 'SGD', 'batch_size': 16, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:56:02,910] Trial 26 finished with value: 0.6133333333333333 and parameters: {'num_conv_layers': 2, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.5, 'learning_rate': 0.00016474369603323234, 'weight_decay': 3.727652449643366e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:57:46,938] Trial 27 finished with value: 0.5466666666666666 and parameters: {'num_conv_layers': 3, 'num_filters': 64, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0013415531579354311, 'weight_decay': 9.735103412188656e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 07:58:58,358] Trial 28 finished with value: 0.6 and parameters: {'num_conv_layers': 2, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 2, 'fc_layer_size': 128, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.0002638063490889496, 'weight_decay': 0.002737208617324671, 'optimizer': 'RMSprop', 'batch_size': 64, 'num_epochs': 50}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:00:28,741] Trial 29 finished with value: 0.5733333333333334 and parameters: {'num_conv_layers': 3, 'num_filters': 64, 'kernel_size': 5, 'num_fc_layers': 3, 'fc_layer_size': 256, 'dropout_rate': 0.2, 'learning_rate': 0.002167586608497705, 'weight_decay': 0.0019908465434471698, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:02:13,622] Trial 30 finished with value: 0.4666666666666667 and parameters: {'num_conv_layers': 2, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.5, 'learning_rate': 0.00029764177943483007, 'weight_decay': 0.0002850004363222136, 'optimizer': 'SGD', 'batch_size': 32, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:03:27,473] Trial 31 finished with value: 0.5733333333333334 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.00042814122005535815, 'weight_decay': 8.995404848017e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 50}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:04:41,788] Trial 32 finished with value: 0.6266666666666667 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0006080326552387564, 'weight_decay': 2.220978235890461e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 50}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:06:11,105] Trial 33 finished with value: 0.68 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0002936792004930485, 'weight_decay': 5.489534521757603e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:07:28,215] Trial 34 finished with value: 0.49333333333333335 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 5, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.0007789423441893139, 'weight_decay': 0.00011410437767302201, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 50}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:08:25,862] Trial 35 finished with value: 0.5466666666666666 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.5, 'learning_rate': 0.00022394230561445592, 'weight_decay': 6.829597721027564e-05, 'optimizer': 'RMSprop', 'batch_size': 64, 'num_epochs': 40}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:09:38,548] Trial 36 finished with value: 0.6533333333333333 and parameters: {'num_conv_layers': 3, 'num_filters': 64, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 128, 'dropout_rate': 0.4, 'learning_rate': 0.00033428574534792273, 'weight_decay': 1.030136889247318e-05, 'optimizer': 'RMSprop', 'batch_size': 32, 'num_epochs': 50}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:11:06,316] Trial 37 finished with value: 0.41333333333333333 and parameters: {'num_conv_layers': 2, 'num_filters': 32, 'kernel_size': 5, 'num_fc_layers': 2, 'fc_layer_size': 64, 'dropout_rate': 0.5, 'learning_rate': 0.0005011558990348181, 'weight_decay': 3.169372751429347e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:12:04,194] Trial 38 finished with value: 0.44 and parameters: {'num_conv_layers': 1, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.009832938066128024, 'weight_decay': 0.0003724052191093362, 'optimizer': 'RMSprop', 'batch_size': 64, 'num_epochs': 40}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:13:17,201] Trial 39 finished with value: 0.56 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 64, 'dropout_rate': 0.4, 'learning_rate': 0.00018280324246878902, 'weight_decay': 0.0002198159079932879, 'optimizer': 'SGD', 'batch_size': 16, 'num_epochs': 50}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:14:15,009] Trial 40 finished with value: 0.44 and parameters: {'num_conv_layers': 2, 'num_filters': 32, 'kernel_size': 5, 'num_fc_layers': 1, 'fc_layer_size': 128, 'dropout_rate': 0.4, 'learning_rate': 0.0011127488340364176, 'weight_decay': 0.00013923512681185605, 'optimizer': 'RMSprop', 'batch_size': 32, 'num_epochs': 40}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:15:44,167] Trial 41 finished with value: 0.6666666666666666 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0002552511766107912, 'weight_decay': 5.339308015252532e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:17:13,195] Trial 42 finished with value: 0.5733333333333334 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0003858529027235208, 'weight_decay': 6.659288371140427e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:18:55,636] Trial 43 finished with value: 0.6933333333333334 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0005399195502584401, 'weight_decay': 1.9786260514527644e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:20:38,651] Trial 44 finished with value: 0.6666666666666666 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0005801027109963844, 'weight_decay': 1.643916244841456e-05, 'optimizer': 'Adam', 'batch_size': 16, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:22:19,050] Trial 45 finished with value: 0.68 and parameters: {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 2, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0007943953176558658, 'weight_decay': 2.4636464511592113e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:23:58,047] Trial 46 finished with value: 0.5866666666666667 and parameters: {'num_conv_layers': 3, 'num_filters': 128, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 64, 'dropout_rate': 0.5, 'learning_rate': 0.00045985554962343586, 'weight_decay': 1.9352563543399368e-05, 'optimizer': 'RMSprop', 'batch_size': 64, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:25:40,764] Trial 47 finished with value: 0.6266666666666667 and parameters: {'num_conv_layers': 3, 'num_filters': 64, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.30000000000000004, 'learning_rate': 0.0006797081226031933, 'weight_decay': 1.3724886380670132e-05, 'optimizer': 'Adam', 'batch_size': 16, 'num_epochs': 70}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:27:06,314] Trial 48 finished with value: 0.49333333333333335 and parameters: {'num_conv_layers': 1, 'num_filters': 16, 'kernel_size': 5, 'num_fc_layers': 2, 'fc_layer_size': 256, 'dropout_rate': 0.2, 'learning_rate': 0.001749335214818428, 'weight_decay': 3.382403688447914e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}. Best is trial 15 with value: 0.7066666666666667.
# [I 2025-12-30 08:27:50,696] Trial 49 finished with value: 0.48 and parameters: {'num_conv_layers': 3, 'num_filters': 32, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.00032955741126835554, 'weight_decay': 4.4347379900509374e-05, 'optimizer': 'SGD', 'batch_size': 32, 'num_epochs': 30}. Best is trial 15 with value: 0.7066666666666667.

# %%
print("\nBest Hyperparameters:")
print(study.best_params)
# Out:
# Best Hyperparameters:
# {'num_conv_layers': 3, 'num_filters': 16, 'kernel_size': 3, 'num_fc_layers': 1, 'fc_layer_size': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0005794624755319799, 'weight_decay': 2.8848686263950447e-05, 'optimizer': 'RMSprop', 'batch_size': 16, 'num_epochs': 60}

# %%
print("\nBest Accuracy:")
print(study.best_value)
# Out:
# Best Accuracy:
# 0.7066666666666667
